# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import shutil
import random

import torch
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.utils as vutils

# %%
# Configuration
class ARGS():
    outputs_dir = 'output'
    latent_space = 100
    batch_size = 64
    epochs = 50
    b1 = 0.5
    b2 = 0.9
    lr = 0.002
    model_location = '../input/ganpth2/final_g.pth'
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    outputs_dir = os.path.join(outputs_dir,  "GAN")
    if not os.path.exists(outputs_dir):
        os.makedirs(outputs_dir)
    
    seed = 42
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    
args = ARGS()

# %%
class Generator(nn.Module):
    def __init__(self,
                latent_space : int = 100,
                ) -> None:
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            # Input : 100
            nn.ConvTranspose2d(100, 512, 4, 1, 0, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),
            # state size : 512 x 4 x 4
            nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            # state size : 256 x 8 x 8
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            # state size : 128 x 16 x 16
            nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            # state size : 64 x 32 x 32
            nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=True),
            nn.Tanh()
            # output : 3 x 64 x 64
        )

    def forward(self, x: Tensor) -> Tensor:
        out = self.main(x)
        return out

# %%
model = Generator()

# %%
# Load model weights.
state_dict = torch.load(args.model_location, map_location= args.device)
model.load_state_dict(state_dict)
# Start the evaluation mode of the model.
model.eval()
with torch.no_grad():
    for index in range(100):
        # Create an fixed noise
        fixed_noise = torch.randn([args.batch_size, 100, 1, 1], device = args.device)
        # Generate image
        image = model(fixed_noise)
        # Save image
        torchvision.utils.save_image(image, os.path.join(args.outputs_dir, f"{index:03d}.jpg"))
        print(f"The {index + 1:03d} image is being created using the model...")
# Out:
# The 001 image is being created using the model...
# The 002 image is being created using the model...
# The 003 image is being created using the model...
# The 004 image is being created using the model...
# The 005 image is being created using the model...
# The 006 image is being created using the model...
# The 007 image is being created using the model...
# The 008 image is being created using the model...
# The 009 image is being created using the model...
# The 010 image is being created using the model...
# The 011 image is being created using the model...
# The 012 image is being created using the model...
# The 013 image is being created using the model...
# The 014 image is being created using the model...
# The 015 image is being created using the model...
# The 016 image is being created using the model...
# The 017 image is being created using the model...
# The 018 image is being created using the model...
# The 019 image is being created using the model...
# The 020 image is being created using the model...
# The 021 image is being created using the model...
# The 022 image is being created using the model...
# The 023 image is being created using the model...
# The 024 image is being created using the model...
# The 025 image is being created using the model...
# The 026 image is being created using the model...
# The 027 image is being created using the model...
# The 028 image is being created using the model...
# The 029 image is being created using the model...
# The 030 image is being created using the model...
# The 031 image is being created using the model...
# The 032 image is being created using the model...
# The 033 image is being created using the model...
# The 034 image is being created using the model...
# The 035 image is being created using the model...
# The 036 image is being created using the model...
# The 037 image is being created using the model...
# The 038 image is being created using the model...
# The 039 image is being created using the model...
# The 040 image is being created using the model...
# The 041 image is being created using the model...
# The 042 image is being created using the model...
# The 043 image is being created using the model...
# The 044 image is being created using the model...
# The 045 image is being created using the model...
# The 046 image is being created using the model...
# The 047 image is being created using the model...
# The 048 image is being created using the model...
# The 049 image is being created using the model...
# The 050 image is being created using the model...
# The 051 image is being created using the model...
# The 052 image is being created using the model...
# The 053 image is being created using the model...
# The 054 image is being created using the model...
# The 055 image is being created using the model...
# The 056 image is being created using the model...
# The 057 image is being created using the model...
# The 058 image is being created using the model...
# The 059 image is being created using the model...
# The 060 image is being created using the model...
# The 061 image is being created using the model...
# The 062 image is being created using the model...
# The 063 image is being created using the model...
# The 064 image is being created using the model...
# The 065 image is being created using the model...
# The 066 image is being created using the model...
# The 067 image is being created using the model...
# The 068 image is being created using the model...
# The 069 image is being created using the model...
# The 070 image is being created using the model...
# The 071 image is being created using the model...
# The 072 image is being created using the model...
# The 073 image is being created using the model...
# The 074 image is being created using the model...
# The 075 image is being created using the model...
# The 076 image is being created using the model...
# The 077 image is being created using the model...
# The 078 image is being created using the model...
# The 079 image is being created using the model...
# The 080 image is being created using the model...
# The 081 image is being created using the model...
# The 082 image is being created using the model...
# The 083 image is being created using the model...
# The 084 image is being created using the model...
# The 085 image is being created using the model...
# The 086 image is being created using the model...
# The 087 image is being created using the model...
# The 088 image is being created using the model...
# The 089 image is being created using the model...
# The 090 image is being created using the model...
# The 091 image is being created using the model...
# The 092 image is being created using the model...
# The 093 image is being created using the model...
# The 094 image is being created using the model...
# The 095 image is being created using the model...
# The 096 image is being created using the model...
# The 097 image is being created using the model...
# The 098 image is being created using the model...
# The 099 image is being created using the model...
# The 100 image is being created using the model...

# %%
# Zip folder for download
# !zip -r file.zip ./output/GAN
# Out:
# updating: output/GAN/ (stored 0%)
#   adding: output/GAN/058.jpg (deflated 0%)
#   adding: output/GAN/025.jpg (deflated 0%)
#   adding: output/GAN/061.jpg (deflated 0%)
#   adding: output/GAN/069.jpg (deflated 0%)
#   adding: output/GAN/049.jpg (deflated 0%)
#   adding: output/GAN/092.jpg (deflated 0%)
#   adding: output/GAN/029.jpg (deflated 0%)
#   adding: output/GAN/028.jpg (deflated 0%)
#   adding: output/GAN/053.jpg (deflated 0%)
#   adding: output/GAN/010.jpg (deflated 0%)
#   adding: output/GAN/059.jpg (deflated 0%)
#   adding: output/GAN/016.jpg (deflated 0%)
#   adding: output/GAN/019.jpg (deflated 0%)
#   adding: output/GAN/093.jpg (deflated 0%)
#   adding: output/GAN/045.jpg (deflated 0%)
#   adding: output/GAN/032.jpg (deflated 0%)
#   adding: output/GAN/060.jpg (deflated 0%)
#   adding: output/GAN/083.jpg (deflated 0%)
#   adding: output/GAN/039.jpg (deflated 0%)
#   adding: output/GAN/013.jpg (deflated 0%)
#   adding: output/GAN/051.jpg (deflated 0%)
#   adding: output/GAN/037.jpg (deflated 0%)
#   adding: output/GAN/054.jpg (deflated 0%)
#   adding: output/GAN/055.jpg (deflated 0%)
#   adding: output/GAN/031.jpg (deflated 0%)
#   adding: output/GAN/066.jpg (deflated 0%)
#   adding: output/GAN/075.jpg (deflated 0%)
#   adding: output/GAN/001.jpg (deflated 0%)
#   adding: output/GAN/021.jpg (deflated 0%)
#   adding: output/GAN/094.jpg (deflated 0%)
#   adding: output/GAN/042.jpg (deflated 0%)
#   adding: output/GAN/073.jpg (deflated 0%)
#   adding: output/GAN/084.jpg (deflated 0%)
#   adding: output/GAN/011.jpg (deflated 0%)
#   adding: output/GAN/096.jpg (deflated 0%)
#   adding: output/GAN/044.jpg (deflated 0%)
#   adding: output/GAN/052.jpg (deflated 0%)
#   adding: output/GAN/014.jpg (deflated 0%)
